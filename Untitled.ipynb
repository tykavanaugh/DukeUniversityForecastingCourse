# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import scipy
from sklearn import datasets, linear_model
import statsmodels.api as sm
# %matplotlib inline
#https://people.duke.edu/~rnau/411home.htm
np.random.seed(1)

# %%
df = pd.read_excel('Mean_model_for_X1.xlsx')
df.head()
# Out:
#    T    X1  Unnamed: 2  Unnamed: 3  \
# 0  1  25.0         NaN         NaN
# 1  2  42.0         NaN         NaN
# 2  3  54.0         NaN         NaN
# 3  4  26.0         NaN         NaN
# 4  5  39.0         NaN         NaN
#
#   Data and model to accompany the discussion on this web page:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3             The model was produced with RegressIt:
# 4                                                NaN
#
#                                  Unnamed: 5
# 0  http://people.duke.edu/~rnau/411mean.htm
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                      http://regressit.com

# %%
df.drop(df.columns[[2,3,4,5]], axis=1, inplace=True)

# %%
df.drop(30,inplace=True)

# %%
df
# Out:
#      T    X1
# 0    1  25.0
# 1    2  42.0
# 2    3  54.0
# 3    4  26.0
# 4    5  39.0
# 5    6  34.0
# 6    7  24.0
# 7    8  37.0
# 8    9  23.0
# 9   10  40.0
# 10  11  30.0
# 11  12  15.0
# 12  13  23.0
# 13  14  40.0
# 14  15  32.0
# 15  16  46.0
# 16  17  50.0
# 17  18  26.0
# 18  19  44.0
# 19  20  58.0
# 20  21  48.0
# 21  22  46.0
# 22  23  36.0
# 23  24  55.0
# 24  25  55.0
# 25  26  41.0
# 26  27  35.0
# 27  28  64.0
# 28  29  38.0
# 29  30  29.0

# %%
plt.plot(df)
linear_model.LogisticRegression(df)
linear_model.pr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty=     T    X1
# 0    1  25.0
# 1    2  42.0
# 2    3  54.0
# 3    4  26.0
# 4    5  39.0
# 5    6  34.0
# 6    7  24.0
# 7    8  37.0
# 8    9  23.0
# 9   10  40.0
# 10  11  30.0
# 11  12  15.0
# 12  13  23.0
# 13  14  40.0
# 14  15  32.0
# 15  16  46.0
# 16  17  50.0
# 17  18  26.0
# 18  19  44.0
# 19  20  58.0
# 20  21  48.0
# 21  22  46.0
# 22  23  36.0
# 23  24  55.0
# 24  25  55.0
# 25  26  41.0
# 26  27  35.0
# 27  28  64.0
# 28  29  38.0
# 29  30  29.0,
#           random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#           warm_start=False)
